# %%
pip install tensorflowjs matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/31/3c/80816f027b3a4a28cd2a0a6ef7f89a2db22310e945cd886ec25bfb399221/matplotlib-3.10.7-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/19/e8/6026ed58a64563186a9ee3f29f41261fd1828f527dd93d33b60feca63352/contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/88/8f/a55b5550cd33cd1028601df41acd057d4be20efa5c958f417b0c0613924d/fonttools-4.60.1-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/114.6 kB ? eta -:--:--
# ...

# %%
#Importing Libraries
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# data_dir='/content/drive/MyDrive/butterflyml/Butterfly/butterfly_photos/'
# print(data_dir)
data_dir='C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/'
print(data_dir)
# Out:
# C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/

# %%
data_dir=tf.keras.preprocessing.image_dataset_from_directory(data_dir)
# Out:
# Found 1303 files belonging to 6 classes.

# %%
count = 0
dirs = os.listdir('C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/')
for dir in dirs:
    files = list(os.listdir('C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/'+dir))
    print( dir +' Folder has '+ str(len(files)) + 'C:/Users/jerwin/Documents/butterfly_photos/pupae defects/')
    count = count + len(files)
print( 'Images Folder has '+ str(count) + 'C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/')
# Out:
# Ant bites Folder has 264C:/Users/jerwin/Documents/butterfly_photos/pupae defects/
# Deformed body Folder has 165C:/Users/jerwin/Documents/butterfly_photos/pupae defects/
# Healthy Pupae Folder has 781C:/Users/jerwin/Documents/butterfly_photos/pupae defects/
# Old Pupa Folder has 47C:/Users/jerwin/Documents/butterfly_photos/pupae defects/
# Overbend Folder has 20C:/Users/jerwin/Documents/butterfly_photos/pupae defects/
# Stretch abdomen Folder has 27C:/Users/jerwin/Documents/butterfly_photos/pupae defects/
# Images Folder has 1304C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/

# %%
base_dir = 'C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/'
img_size = 180
batch = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'training',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))

val_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'validation',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))
# Out:
# Found 1303 files belonging to 6 classes.
# Using 1043 files for training.
# Found 1303 files belonging to 6 classes.
# Using 260 files for validation.

# %%
pupaedefects_names = train_ds.class_names
pupaedefects_names
# Out:
# ['Ant bites',
#  'Deformed body',
#  'Healthy Pupae',
#  'Old Pupa',
#  'Overbend',
#  'Stretch abdomen']

# %%
import matplotlib.pyplot as plt

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3,3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(pupaedefects_names[labels[i]])
        plt.axis('off')

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ##Data Augmentation

# %%
# data_augmentation = Sequential([
#     layers.RandomFlip("horizontal", input_shape = (img_size,img_size,3)),
#     layers.RandomRotation(0.1),
#     layers.RandomZoom(0.1)
# ])

from tensorflow.keras.layers import Input, RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.models import Model
inputs = Input(shape=(img_size, img_size, 3))
x = RandomFlip("horizontal")(inputs)
x = RandomRotation(0.1)(x)
x = RandomZoom(0.1)(x)
data_augmentation = Model(inputs, x)

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        images = data_augmentation(images)
        plt.subplot(3,3, i+1)
        plt.imshow(images[0].numpy().astype('uint8'))
        plt.axis('off')

# %% [markdown]
# ##Model Creation

# %%
model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(6)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 32)     │         4,640 │
# ...

# %%
history = model.fit(train_ds, epochs=15, validation_data=val_ds)
# Out:
# Epoch 1/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 319ms/step - accuracy: 0.6884 - loss: 0.8541 - val_accuracy: 0.7615 - val_loss: 0.6098
# Epoch 2/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.8389 - loss: 0.4936 - val_accuracy: 0.8308 - val_loss: 0.4234
# Epoch 3/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.8648 - loss: 0.4070 - val_accuracy: 0.8846 - val_loss: 0.4020
# Epoch 4/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.8859 - loss: 0.3147 - val_accuracy: 0.8885 - val_loss: 0.3588
# Epoch 5/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.9310 - loss: 0.2420 - val_accuracy: 0.9308 - val_loss: 0.2269
# Epoch 6/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.9406 - loss: 0.1679 - val_accuracy: 0.8885 - val_loss: 0.4014
# Epoch 7/15
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.9310 - loss: 0.1914 - val_accuracy: 0.9500 - val_loss: 0.1898
# Epoch 8/15
# ...

# %%
def classify_images(image_path):
    input_image = tf.keras.utils.load_img(image_path, target_size=(180,180))
    input_image_array = tf.keras.utils.img_to_array(input_image)
    input_image_exp_dim = tf.expand_dims(input_image_array,0)

    predictions = model.predict(input_image_exp_dim)
    result = tf.nn.softmax(predictions[0])
    outcome = 'The Image belongs to ' + pupaedefects_names[np.argmax(result)] + ' with a score of '+ str(np.max(result)*100)
    return outcome

# %%
classify_images('C:/Users/jerwin/Documents/GitHub/butterfly_photos/pupae defects/Deformed body/deformedBody51.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 'The Image belongs to Deformed body with a score of 95.04296'

# %%
model.save('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/model/model_Pupae_Defects.keras')

# %%
model.save('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/model/model_Pupae_Defects.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model = load_model('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/model/model_Pupae_Defects.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Check the loaded model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 32)     │         4,640 │
# ...

# %%
# Save the model architecture to a JSON file
# model_json = model.to_json('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylepC:/Users/jerwin/Documents/GitHub/PrettyLep/json/model_Pupae_Defects.json', 'w')
    
#     json_file.write(model_json)

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/model/model_Pupae_Defects.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Save the model architecture to a JSON file
model_json = model.to_json()
with open("C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/json/model_Pupae_Defects.json", "w") as json_file:
    json_file.write(model_json)

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
# ...existing code...

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score

# Evaluate model and plot confusion matrix + F1 score
y_true = []
y_pred = []

for images, labels in val_ds.unbatch():
    img_array = tf.expand_dims(images, 0)  # Add batch dimension
    preds = model.predict(img_array, verbose=0)
    pred_label = np.argmax(preds, axis=1)[0]
    y_true.append(labels.numpy())
    y_pred.append(pred_label)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pupaedefects_names)
disp.plot(ax=ax, cmap='Blues', xticks_rotation=90)
plt.title("Confusion Matrix")
plt.show()

# F1 Score (macro and weighted)
f1_macro = f1_score(y_true, y_pred, average='macro')
f1_weighted = f1_score(y_true, y_pred, average='weighted')
print(f"F1 Score (macro): {f1_macro:.4f}")
print(f"F1 Score (weighted): {f1_weighted:.4f}")
# ...existing code...
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[67], line 3
#       1 # ...existing code...
# ----> 3 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
#       5 # Evaluate model and plot confusion matrix + F1 score
#       6 y_true = []
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.metrics import classification_report
import numpy as np

y_true = ['Ant bites',
 'Deformed body',
 'Healthy Pupae',
 'Old Pupa',
 'Overbend',
 'Stretch abdomen']

y_pred = [['Ant bites',
 'Deformed body',
 'Healthy Pupae',
 'Old Pupa',
 'Overbend',
 'Stretch abdomen']]


# Flatten y_pred if nested
if isinstance(y_pred, list) and len(y_pred) == 1 and isinstance(y_pred[0], (list, np.ndarray)):
    y_pred_flat = list(y_pred[0])
else:
    y_pred_flat = list(np.asarray(y_pred).ravel())

# Sanity check
if len(y_true) != len(y_pred_flat):
    raise ValueError(f"Length mismatch: y_true={len(y_true)} vs y_pred={len(y_pred_flat)}")

# Generate report (labels inferred)
report = classification_report(y_true, y_pred_flat, zero_division=0)
print(report)
