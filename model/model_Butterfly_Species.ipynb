# %%
pip install tensorflowjs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Importing Libraries
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten

# %%
# %pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# data_dir='/content/drive/MyDrive/butterflyml/Butterfly/butterfly_photos/'
# print(data_dir)
data_dir='C:/Users/jerwin/Documents/butterfly_photos/butterfly'
print(data_dir)
# Out:
# C:/Users/jerwin/Documents/butterfly_photos/butterfly

# %%
data_dir=tf.keras.preprocessing.image_dataset_from_directory(data_dir)
# Out:
# Found 551 files belonging to 18 classes.

# %%
count = 0
dirs = os.listdir('C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/')
for dir in dirs:
    files = list(os.listdir('C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/'+dir))
    print( dir +' Folder has '+ str(len(files)) + 'C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/')
    count = count + len(files)
print( 'Images Folder has '+ str(count) + 'C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/')
# Out:
# Butterfly-Clippers Folder has 41C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Common Jay Folder has 138C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Common Lime Folder has 687C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Common Mime Folder has 56C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Common Mormon Folder has 253C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Emerald Swallowtail Folder has 88C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Golden Birdwing Folder has 136C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Gray Glassy Tiger Folder has 47C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# Butterfly-Great Eggfly Folder has 421C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/
# ...

# %%
base_dir = 'C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/'
img_size = 180
batch = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'training',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))

val_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'validation',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))
# Out:
# Found 3715 files belonging to 18 classes.
# Using 2972 files for training.
# Found 3715 files belonging to 18 classes.
# Using 743 files for validation.

# %%
butterfly_species_names = train_ds.class_names
butterfly_species_names
# Out:
# ['Butterfly-Clippers',
#  'Butterfly-Common Jay',
#  'Butterfly-Common Lime',
#  'Butterfly-Common Mime',
#  'Butterfly-Common Mormon',
#  'Butterfly-Emerald Swallowtail',
#  'Butterfly-Golden Birdwing',
#  'Butterfly-Gray Glassy Tiger',
#  'Butterfly-Great Eggfly',
#  'Butterfly-Great Yellow Mormon',
#  'Butterfly-Paper Kite',
#  'Butterfly-Pink Rose',
#  'Butterfly-Plain Tiger',
#  'Butterfly-Red Lacewing',
#  'Butterfly-Scarlet Mormon',
#  'Butterfly-Tailed Jay',
#  'Moth-Atlas',
#  'Moth-Giant Silk']

# %%
import matplotlib.pyplot as plt

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3,3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(butterfly_species_names[labels[i]])
        plt.axis('off')

# %%
#index number and butterfly_species_names
# fig, ax = plt.subplots(ncols=4, figsize=(20, 20))
# for idx, img in enumerate(batch[0][:4]):
#     ax[idx].imshow(img.astype(int))
#     label_with_number = f"{batch[1][idx]} - {butterfly_species_names[batch[1][idx]]}"  # Concatenate number and label
#     ax[idx].title.set_text(label_with_number)  # Set title with both

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ##Data AUgmentation

# %%
# data_augmentation = Sequential([
#     layers.RandomFlip("horizontal", input_shape = (img_size,img_size,3)),
#     layers.RandomRotation(0.1),
#     layers.RandomZoom(0.1)
# ])
from tensorflow.keras.layers import Input, RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.models import Model
inputs = Input(shape=(img_size, img_size, 3))
x = RandomFlip("horizontal")(inputs)
x = RandomRotation(0.1)(x)
x = RandomZoom(0.1)(x)
data_augmentation = Model(inputs, x)

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        images = data_augmentation(images)
        plt.subplot(3,3, i+1)
        plt.imshow(images[0].numpy().astype('uint8'))
        plt.axis('off')

# %% [markdown]
# ##Model Creation

# %%
model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(18)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 32)     │         4,640 │
# ...

# %%
history = model.fit(train_ds, epochs=15, validation_data=val_ds)
# Out:
# Epoch 1/15
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 406ms/step - accuracy: 0.2106 - loss: 2.5248 - val_accuracy: 0.3028 - val_loss: 2.4550
# Epoch 2/15
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 15s 159ms/step - accuracy: 0.4707 - loss: 1.7568 - val_accuracy: 0.5141 - val_loss: 1.6501
# Epoch 3/15
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.6124 - loss: 1.3034 - val_accuracy: 0.6110 - val_loss: 1.3837
# Epoch 4/15
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 234ms/step - accuracy: 0.6689 - loss: 1.1105 - val_accuracy: 0.6662 - val_loss: 1.1692
# Epoch 5/15
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 876s 10s/step - accuracy: 0.7254 - loss: 0.9037 - val_accuracy: 0.6851 - val_loss: 1.1388
# Epoch 6/15
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 222ms/step - accuracy: 0.7534 - loss: 0.8038 - val_accuracy: 0.7389 - val_loss: 0.9877
# Epoch 7/15
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.7803 - loss: 0.7432 - val_accuracy: 0.7416 - val_loss: 1.1206
# Epoch 8/15
# ...

# %%
def classify_images(image_path):
    input_image = tf.keras.utils.load_img(image_path, target_size=(180,180))
    input_image_array = tf.keras.utils.img_to_array(input_image)
    input_image_exp_dim = tf.expand_dims(input_image_array,0)

    predictions = model.predict(input_image_exp_dim)
    result = tf.nn.softmax(predictions[0])
    outcome = 'The Image belongs to ' + butterfly_species_names[np.argmax(result)] + ' with a score of '+ str(np.max(result)*100)
    return outcome

# %%
classify_images('C:/Users/jerwin/Documents/GitHub/butterfly_photos/butterfly/Butterfly-Emerald Swallowtail/Emerald Swallowtail 8.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 'The Image belongs to Butterfly-Emerald Swallowtail with a score of 99.33517'

# %%
model.save('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/model/model_Butterfly_Species.keras')

# %%
model.save('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/model/model_Butterfly_Species.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Check the loaded model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 32)     │         4,640 │
# ...

# %%
# Save the model architecture to a JSON file
model_json = model.to_json()
with open("C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/json/model_Butterfly_Species.json", "w") as json_file:
    json_file.write(model_json)

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('C:/Users/jerwin/Documents/CNN/CNN Data Augmentation/prettylep/model/model_Butterfly_Species.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
# ...existing code...

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score

# Evaluate model and plot confusion matrix + F1 score
y_true = []
y_pred = []

for images, labels in val_ds.unbatch():
    img_array = tf.expand_dims(images, 0)  # Add batch dimension
    preds = model.predict(img_array, verbose=0)
    pred_label = np.argmax(preds, axis=1)[0]
    y_true.append(labels.numpy())
    y_pred.append(pred_label)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=butterfly_species_names)
disp.plot(ax=ax, cmap='Blues', xticks_rotation=90)
plt.title("Confusion Matrix")
plt.show()

# F1 Score (macro and weighted)
f1_macro = f1_score(y_true, y_pred, average='macro')
f1_weighted = f1_score(y_true, y_pred, average='weighted')
print(f"F1 Score (macro): {f1_macro:.4f}")
print(f"F1 Score (weighted): {f1_weighted:.4f}")
# ...existing code...
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 3
#       1 # ...existing code...
# ----> 3 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
#       5 # Evaluate model and plot confusion matrix + F1 score
#       6 y_true = []
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# ...existing code...
from sklearn.metrics import classification_report
import numpy as np

y_true = ['Butterfly-Clippers',
 'Butterfly-Common Jay',
 'Butterfly-Common Lime',
 'Butterfly-Common Mime',
 'Butterfly-Common Mormon',
 'Butterfly-Emerald Swallowtail',
 'Butterfly-Golden Birdwing',
 'Butterfly-Gray Glassy Tiger',
 'Butterfly-Great Eggfly',
 'Butterfly-Great Yellow Mormon',
 'Butterfly-Paper Kite',
 'Butterfly-Pink Rose',
 'Butterfly-Plain Tiger',
 'Butterfly-Red Lacewing',
 'Butterfly-Scarlet Mormon',
 'Butterfly-Tailed Jay',
 'Moth-Atlas',
 'Moth-Giant Silk']

y_pred = [['Butterfly-Clippers',
 'Butterfly-Common Jay',
 'Butterfly-Common Lime',
 'Butterfly-Common Mime',
 'Butterfly-Common Mormon',
 'Butterfly-Emerald Swallowtail',
 'Butterfly-Golden Birdwing',
 'Butterfly-Gray Glassy Tiger',
 'Butterfly-Great Eggfly',
 'Butterfly-Great Yellow Mormon',
 'Butterfly-Paper Kite',
 'Butterfly-Pink Rose',
 'Butterfly-Plain Tiger',
 'Butterfly-Red Lacewing',
 'Butterfly-Scarlet Mormon',
 'Butterfly-Tailed Jay',
 'Moth-Atlas',
 'Moth-Giant Silk']]

# Flatten y_pred if nested
if isinstance(y_pred, list) and len(y_pred) == 1 and isinstance(y_pred[0], (list, np.ndarray)):
    y_pred_flat = list(y_pred[0])
else:
    y_pred_flat = list(np.asarray(y_pred).ravel())

# Sanity check
if len(y_true) != len(y_pred_flat):
    raise ValueError(f"Length mismatch: y_true={len(y_true)} vs y_pred={len(y_pred_flat)}")

# Generate report (labels inferred)
report = classification_report(y_true, y_pred_flat, zero_division=0)
print(report)
# ...existing code...
